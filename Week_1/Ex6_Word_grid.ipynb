# %% [markdown]
# # 🧩 Word Grid
#
# You are given a grid of letters, and your task is to **find the number of times a word appears** in the grid.
#
# - A word can be read:
#   - **Horizontally**
#   - **Vertically**
#   - **Diagonally**
# - Words can be read in **both directions** (forwards and backwards).
# - **If a word and its reverse share the same path**, it is only counted **once**.
#
# ---
#
# ## 🛠 File: `wordgrid.py`
#
# You must implement a class `WordFinder` with the following methods:
#
# ### 🔹 `set_grid(self, grid: list[str]) -> None`
#
# - Sets the content of the grid.
# - `grid` is a list of strings, where each string represents a **row** of the grid.
#
# ### 🔹 `count(self, word: str) -> int`
#
# - Returns the **number of distinct occurrences** of the word in the grid (including reversed occurrences, but not double-counting them on the same path).
#
# ---
#
# ## 🧪 Example
#
# Given the following grid:
#
# ```
# ABCD
# EFGH
# IJKL
# MNOP
# ```
#
# Calling `count("AB")` should return `1` (horizontal match).
# Calling `count("BA")` should return `1` as well — but counted **once**.
#
# ---
#
# ## 🔒 Constraints
#
# - Grid size: up to **20×20**
# - All characters: **uppercase A–Z**
# - The `count` function must consider:
#   - 8 possible directions
#   - Each word and its reverse only once per path
#
# ---
#
# ## ✅ Submission Checklist
#
# - [ ] `WordFinder` class implemented
# - [ ] `set_grid(grid)` works correctly
# - [ ] `count(word)` detects all valid occurrences without double-counting
# - [ ] Handles grid sizes up to 20×20
# - [ ] Correct handling of diagonals and reversals
#
# ---
#
# Let me know if you’d like the actual Python implementation for the `WordFinder` class!

# %%
class WordFinder:
    def set_grid(self, grid):
        # TODO

    def count(self, word):
        # TODO

if __name__ == "__main__":
    grid = ["TIRATIRA",
            "IRATIRAT",
            "RATIRATI",
            "ATIRATIR"]

    finder = WordFinder()
    finder.set_grid(grid)

    print(finder.count("TIRA")) # 7 
    print(finder.count("TA")) # 13
    print(finder.count("RITARI")) # 3
    print(finder.count("A")) # 8
    print(finder.count("AA")) # 6
    print(finder.count("RAITA")) # 0
